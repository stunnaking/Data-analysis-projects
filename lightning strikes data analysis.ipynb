# %%
#Import statements
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('eda_structuring_with_python_dataset1.csv')
df.head(10)
# Out:
#          date  number_of_strikes center_point_geom
# 0  2018-01-03                194     POINT(-75 27)
# 1  2018-01-03                 41   POINT(-78.4 29)
# 2  2018-01-03                 33   POINT(-73.9 27)
# 3  2018-01-03                 38   POINT(-73.8 27)
# 4  2018-01-03                 92     POINT(-79 28)
# 5  2018-01-03                119     POINT(-78 28)
# 6  2018-01-03                 35   POINT(-79.3 28)
# 7  2018-01-03                 60   POINT(-79.1 28)
# 8  2018-01-03                 41   POINT(-78.7 28)
# 9  2018-01-03                119   POINT(-78.6 28)

# %%
#Convert data column to datetime
df['date'] = pd.to_datetime(df['date'])
df.head(10)
# Out:
#         date  number_of_strikes center_point_geom
# 0 2018-01-03                194     POINT(-75 27)
# 1 2018-01-03                 41   POINT(-78.4 29)
# 2 2018-01-03                 33   POINT(-73.9 27)
# 3 2018-01-03                 38   POINT(-73.8 27)
# 4 2018-01-03                 92     POINT(-79 28)
# 5 2018-01-03                119     POINT(-78 28)
# 6 2018-01-03                 35   POINT(-79.3 28)
# 7 2018-01-03                 60   POINT(-79.1 28)
# 8 2018-01-03                 41   POINT(-78.7 28)
# 9 2018-01-03                119   POINT(-78.6 28)

# %%
df.shape
# Out:
# (3401012, 3)

# %%
df.drop_duplicates().shape
# Out:
# (3401012, 3)

# %%
df.sort_values(by = 'number_of_strikes', ascending = False).head(10)
# Out:
#              date  number_of_strikes  center_point_geom
# 302758 2018-08-20               2211  POINT(-92.5 35.5)
# 278383 2018-08-16               2142  POINT(-96.1 36.1)
# 280830 2018-08-17               2061  POINT(-90.2 36.1)
# 280453 2018-08-17               2031  POINT(-89.9 35.9)
# 278382 2018-08-16               1902  POINT(-96.2 36.1)
# 11517  2018-02-10               1899  POINT(-95.5 28.1)
# 277506 2018-08-16               1878  POINT(-89.7 31.5)
# 24906  2018-02-25               1833  POINT(-98.7 28.9)
# 284320 2018-08-17               1767    POINT(-90.1 36)
# 24825  2018-02-25               1741      POINT(-98 29)

# %%
df.center_point_geom.value_counts()
# Out:
# POINT(-81.5 22.5)     108
# POINT(-84.1 22.4)     108
# POINT(-82.5 22.9)     107
# POINT(-82.7 22.9)     107
# POINT(-82.5 22.8)     106
#                      ...
# POINT(-119.3 35.1)      1
# POINT(-119.3 35)        1
# POINT(-119.6 35.6)      1
# POINT(-119.4 35.6)      1
# POINT(-58.5 45.3)       1
# Name: center_point_geom, Length: 170855, dtype: int64

# %%
df.center_point_geom.value_counts()[:20].rename_axis('unique_values').reset_index(name='counts').style.background_gradient()
# Out:
# <style type="text/css">
# #T_9114d_row0_col1, #T_9114d_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9114d_row2_col1, #T_9114d_row3_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_9114d_row4_col1, #T_9114d_row5_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_9114d_row6_col1, #T_9114d_row7_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_9114d_row8_col1, #T_9114d_row9_col1 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_9114d_row10_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_9114d_row11_col1, #T_9114d_row12_col1, #T_9114d_row13_col1, #T_9114d_row14_col1, #T_9114d_row15_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_9114d_row16_col1, #T_9114d_row17_col1, #T_9114d_row18_col1, #T_9114d_row19_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_9114d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9114d_level0_col0" class="col_heading level0 col0" >unique_values</th>
#       <th id="T_9114d_level0_col1" class="col_heading level0 col1" >counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9114d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9114d_row0_col0" class="data row0 col0" >POINT(-81.5 22.5)</td>
#       <td id="T_9114d_row0_col1" class="data row0 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9114d_row1_col0" class="data row1 col0" >POINT(-84.1 22.4)</td>
#       <td id="T_9114d_row1_col1" class="data row1 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9114d_row2_col0" class="data row2 col0" >POINT(-82.5 22.9)</td>
#       <td id="T_9114d_row2_col1" class="data row2 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9114d_row3_col0" class="data row3 col0" >POINT(-82.7 22.9)</td>
#       <td id="T_9114d_row3_col1" class="data row3 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9114d_row4_col0" class="data row4 col0" >POINT(-82.5 22.8)</td>
#       <td id="T_9114d_row4_col1" class="data row4 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9114d_row5_col0" class="data row5 col0" >POINT(-84.2 22.3)</td>
#       <td id="T_9114d_row5_col1" class="data row5 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9114d_row6_col0" class="data row6 col0" >POINT(-76 20.5)</td>
#       <td id="T_9114d_row6_col1" class="data row6 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9114d_row7_col0" class="data row7 col0" >POINT(-75.9 20.4)</td>
#       <td id="T_9114d_row7_col1" class="data row7 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9114d_row8_col0" class="data row8 col0" >POINT(-82.2 22.9)</td>
#       <td id="T_9114d_row8_col1" class="data row8 col1" >104</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9114d_row9_col0" class="data row9 col0" >POINT(-78 18.2)</td>
#       <td id="T_9114d_row9_col1" class="data row9 col1" >104</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9114d_row10_col0" class="data row10 col0" >POINT(-83.9 22.5)</td>
#       <td id="T_9114d_row10_col1" class="data row10 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9114d_row11_col0" class="data row11 col0" >POINT(-84 22.4)</td>
#       <td id="T_9114d_row11_col1" class="data row11 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9114d_row12_col0" class="data row12 col0" >POINT(-82 22.8)</td>
#       <td id="T_9114d_row12_col1" class="data row12 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9114d_row13_col0" class="data row13 col0" >POINT(-82 22.4)</td>
#       <td id="T_9114d_row13_col1" class="data row13 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9114d_row14_col0" class="data row14 col0" >POINT(-82.3 22.9)</td>
#       <td id="T_9114d_row14_col1" class="data row14 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9114d_row15_col0" class="data row15 col0" >POINT(-78 18.3)</td>
#       <td id="T_9114d_row15_col1" class="data row15 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9114d_row16_col0" class="data row16 col0" >POINT(-84.1 22.5)</td>
#       <td id="T_9114d_row16_col1" class="data row16 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9114d_row17_col0" class="data row17 col0" >POINT(-75.5 20.6)</td>
#       <td id="T_9114d_row17_col1" class="data row17 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9114d_row18_col0" class="data row18 col0" >POINT(-84.2 22.4)</td>
#       <td id="T_9114d_row18_col1" class="data row18 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_9114d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9114d_row19_col0" class="data row19 col0" >POINT(-76 20.4)</td>
#       <td id="T_9114d_row19_col1" class="data row19 col1" >101</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['week'] = df.date.dt.isocalendar().week
df['weekday'] = df.date.dt.day_name()
df.head()
# Out:
#         date  number_of_strikes center_point_geom  week    weekday
# 0 2018-01-03                194     POINT(-75 27)     1  Wednesday
# 1 2018-01-03                 41   POINT(-78.4 29)     1  Wednesday
# 2 2018-01-03                 33   POINT(-73.9 27)     1  Wednesday
# 3 2018-01-03                 38   POINT(-73.8 27)     1  Wednesday
# 4 2018-01-03                 92     POINT(-79 28)     1  Wednesday

# %%
df[['weekday','number_of_strikes']].groupby(['weekday']).mean()
# Out:
#            number_of_strikes
# weekday
# Friday             13.349972
# Monday             13.152804
# Saturday           12.732694
# Sunday             12.324717
# Thursday           13.240594
# Tuesday            13.813599
# Wednesday          13.224568

# %%
#Define order of weekdays for plot
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
#Create boxplot of strike counts for each day of the week
g = sns.boxplot(data=df,
               x= 'weekday',
               y= 'number_of_strikes',
               order = weekday_order,
               showfliers = False
               );
g.set_title('Lightning distribution per weekay (2018)');
